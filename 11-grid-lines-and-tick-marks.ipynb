# %% [markdown]
# ### Chapter 11: Grid Lines and Tick Marks

# %% [markdown]
# #### Plot With Gridlines

# %%
import matplotlib.pyplot as plt

# The Data
x = [1, 2, 3, 4]
y = [234, 124,368, 343]

# Create the figure and axes objects
fig, ax = plt.subplots(1, figsize=(8, 6))

fig.suptitle('Example Of Plot With Grid Lines')

# Plot the data
ax.plot(x,y)

# Show the grid lines as dark grey lines
plt.grid(b = True, 
         which = 'major', 
         color = '#666666', 
         linestyle = '-')
plt.show()
# Out:
# C:\Users\Caíque Miranda\AppData\Local\Temp\ipykernel_13644\2431953304.py:16: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b = True,

# %% [markdown]
# ### Plot With Major and Minor Grid Lines

# %%
import matplotlib.pyplot as plt

# Create the figure and axes objects
fig, ax = plt.subplots(1, figsize=(8, 6))
fig.suptitle('Example Of Plot With Major and Minor Grid Lines')

# Plot the data
ax.plot(x,y)

# Show the major grid lines with dark grey lines
plt.grid(b = True, 
         which = 'major', 
         color = '#666666', 
         linestyle = '-')

# Show the minor grid lines with very faint and almost transparent grey lines
plt.minorticks_on()
plt.grid(b = True, 
         which = 'minor', 
         color = '#999999', 
         linestyle = '-', 
         alpha = 0.2)

plt.show()
# Out:
# C:\Users\Caíque Miranda\AppData\Local\Temp\ipykernel_13644\2357209924.py:11: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b = True,
# C:\Users\Caíque Miranda\AppData\Local\Temp\ipykernel_13644\2357209924.py:18: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b = True,

# %% [markdown]
# ### End.
