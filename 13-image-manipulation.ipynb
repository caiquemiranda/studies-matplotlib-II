# %% [markdown]
# ### Chapter 13: Image manipulation

# %% [markdown]
# #### Opening images

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img = mpimg.imread('img/my_image.png')

# %%
plt.imshow(img);

# %%
img = mpimg.imread('img/my_image.png')
plt.imshow(img)
plt.show()

# %% [markdown]
# ### End.
